# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
### Sentences
sent = [ 'the glass of milk',
        'the glass of juice',
        'the cup of tea',
        'I am a good boy',
        'I am a good developer',
        'understand the meaning of words',
        'your videos are good',]

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
## Define vocabulary size
voc_size = 10000

# %%
### One hot Representation
one_hot_repr = [one_hot(words, voc_size) for words in sent]
one_hot_repr
# Out:
# [[7142, 4784, 3549, 8428],
#  [7142, 4784, 3549, 2364],
#  [7142, 7613, 3549, 395],
#  [4267, 3293, 5201, 3484, 6122],
#  [4267, 3293, 5201, 3484, 7951],
#  [6280, 7142, 7185, 3549, 9351],
#  [9505, 2372, 3170, 3484]]

# %%
## word embedding representation

from tensorflow.keras.layers import Embedding
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length = 8
embedded_docs = pad_sequences(one_hot_repr, padding = 'pre', maxlen = sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 7142 4784 3549 8428]
#  [   0    0    0    0 7142 4784 3549 2364]
#  [   0    0    0    0 7142 7613 3549  395]
#  [   0    0    0 4267 3293 5201 3484 6122]
#  [   0    0    0 4267 3293 5201 3484 7951]
#  [   0    0    0 6280 7142 7185 3549 9351]
#  [   0    0    0    0 9505 2372 3170 3484]]

# %%
## feature representation 
dim = 10

# %%
model = Sequential()
model.add(Embedding(voc_size, dim, input_length = sent_length))
model.compile('adam','mse')
# Out:
# f:\GENERATIVE_AI_PROJECT\RNN_CLASSIFICATION\venv\Lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# array([[[-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [ 0.03465659,  0.02488242,  0.01882757,  0.02702561,
#          -0.0043564 , -0.04798392, -0.01499317, -0.02326448,
#          -0.00690408,  0.03454093],
#         [-0.02264737,  0.02763828, -0.00285298, -0.0406559 ,
#           0.03680868,  0.01323486,  0.0464117 , -0.04980272,
#           0.01985571, -0.03430444],
#         [-0.01883961, -0.03607448, -0.04346418, -0.00464296,
#          -0.02122625,  0.02094008,  0.03548387, -0.02125642,
#           0.006692  ,  0.04350139],
#         [-0.01369144, -0.02663068, -0.03880811,  0.02184329,
#           0.00602639,  0.02797395,  0.02602123, -0.0087837 ,
#           0.01169245, -0.03253011]],
#
#        [[-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [ 0.03465659,  0.02488242,  0.01882757,  0.02702561,
#          -0.0043564 , -0.04798392, -0.01499317, -0.02326448,
#          -0.00690408,  0.03454093],
#         [-0.02264737,  0.02763828, -0.00285298, -0.0406559 ,
#           0.03680868,  0.01323486,  0.0464117 , -0.04980272,
#           0.01985571, -0.03430444],
#         [-0.01883961, -0.03607448, -0.04346418, -0.00464296,
#          -0.02122625,  0.02094008,  0.03548387, -0.02125642,
#           0.006692  ,  0.04350139],
#         [ 0.00141754,  0.02117649, -0.02638456, -0.00134147,
#          -0.01572875, -0.01362541, -0.04430502, -0.02442248,
#          -0.03943612, -0.04176552]],
#
#        [[-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [ 0.03465659,  0.02488242,  0.01882757,  0.02702561,
#          -0.0043564 , -0.04798392, -0.01499317, -0.02326448,
#          -0.00690408,  0.03454093],
#         [ 0.01688256,  0.04838968,  0.01894852,  0.01827073,
#           0.04447946, -0.0059068 ,  0.01868321,  0.04025928,
#          -0.02938609, -0.02693783],
#         [-0.01883961, -0.03607448, -0.04346418, -0.00464296,
#          -0.02122625,  0.02094008,  0.03548387, -0.02125642,
#           0.006692  ,  0.04350139],
#         [ 0.03005359, -0.02119946,  0.00706054, -0.00223627,
#           0.0114509 ,  0.01859326, -0.00338886, -0.0389241 ,
#          -0.03247656, -0.0070347 ]],
#
#        [[-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [ 0.02864684,  0.03736074, -0.00773435, -0.02354604,
#           0.03613881, -0.02174629, -0.00202099,  0.04916928,
#           0.01761517,  0.02680791],
#         [-0.01939674, -0.04171317,  0.04224399,  0.00317989,
#          -0.01858758, -0.01116946, -0.04527792, -0.0216719 ,
#           0.02233047,  0.02186887],
#         [ 0.03441605,  0.01813849, -0.04130558, -0.04189683,
#           0.04386162, -0.04378561, -0.0037057 , -0.04874203,
#          -0.01605282,  0.04679698],
#         [-0.03549304,  0.03632197, -0.02992817,  0.03459184,
#           0.0028531 ,  0.02175337, -0.00326753,  0.0488972 ,
#          -0.03914822, -0.02440828],
#         [-0.04395344, -0.00104589, -0.01301149,  0.00185634,
#          -0.01676934,  0.03594277, -0.04481831,  0.04923359,
#           0.04363178,  0.0147589 ]],
#
#        [[-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [ 0.02864684,  0.03736074, -0.00773435, -0.02354604,
#           0.03613881, -0.02174629, -0.00202099,  0.04916928,
#           0.01761517,  0.02680791],
#         [-0.01939674, -0.04171317,  0.04224399,  0.00317989,
#          -0.01858758, -0.01116946, -0.04527792, -0.0216719 ,
#           0.02233047,  0.02186887],
#         [ 0.03441605,  0.01813849, -0.04130558, -0.04189683,
#           0.04386162, -0.04378561, -0.0037057 , -0.04874203,
#          -0.01605282,  0.04679698],
#         [-0.03549304,  0.03632197, -0.02992817,  0.03459184,
#           0.0028531 ,  0.02175337, -0.00326753,  0.0488972 ,
#          -0.03914822, -0.02440828],
#         [-0.04959628,  0.0022953 , -0.0187123 , -0.01083909,
#          -0.02550014,  0.00360675,  0.0248615 , -0.00809448,
#          -0.01374477, -0.04816127]],
#
#        [[-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [ 0.00607486,  0.03445344, -0.0037594 ,  0.04833889,
#           0.02511753,  0.01595936,  0.0098932 ,  0.04395879,
#           0.03740323, -0.01178424],
#         [ 0.03465659,  0.02488242,  0.01882757,  0.02702561,
#          -0.0043564 , -0.04798392, -0.01499317, -0.02326448,
#          -0.00690408,  0.03454093],
#         [-0.0472013 , -0.02839611,  0.04143004,  0.01015314,
#          -0.02214934,  0.04101506, -0.00784781, -0.01502556,
#          -0.02179589,  0.0435117 ],
#         [-0.01883961, -0.03607448, -0.04346418, -0.00464296,
#          -0.02122625,  0.02094008,  0.03548387, -0.02125642,
#           0.006692  ,  0.04350139],
#         [ 0.02946099,  0.00594737,  0.0144959 ,  0.04359633,
#          -0.04370707, -0.01267071, -0.04949802, -0.04455091,
#           0.00616521,  0.02937788]],
#
#        [[-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02980428,  0.01378066,  0.02142194, -0.03111773,
#           0.04768885, -0.02663767,  0.02914738,  0.02011638,
#          -0.01939211, -0.03862673],
#         [ 0.0031382 , -0.00668667,  0.00060673,  0.03530223,
#          -0.0039538 , -0.03574967, -0.04552964, -0.01303024,
#           0.02696225,  0.02815421],
#         [-0.01047001, -0.02831677, -0.04536576, -0.03313493,
#          -0.02103503,  0.02695603,  0.01959235, -0.03878077,
#          -0.02455059, -0.01082504],
#         [-0.03549304,  0.03632197, -0.02992817,  0.03459184,
#           0.0028531 ,  0.02175337, -0.00326753,  0.0488972 ,
#          -0.03914822, -0.02440828]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 7142, 4784, 3549, 8428], dtype=int32)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# array([[[-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [ 0.03465659,  0.02488242,  0.01882757,  0.02702561,
#          -0.0043564 , -0.04798392, -0.01499317, -0.02326448,
#          -0.00690408,  0.03454093],
#         [-0.02264737,  0.02763828, -0.00285298, -0.0406559 ,
#           0.03680868,  0.01323486,  0.0464117 , -0.04980272,
#           0.01985571, -0.03430444],
#         [-0.01883961, -0.03607448, -0.04346418, -0.00464296,
#          -0.02122625,  0.02094008,  0.03548387, -0.02125642,
#           0.006692  ,  0.04350139],
#         [-0.01369144, -0.02663068, -0.03880811,  0.02184329,
#           0.00602639,  0.02797395,  0.02602123, -0.0087837 ,
#           0.01169245, -0.03253011]],
#
#        [[-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [ 0.03465659,  0.02488242,  0.01882757,  0.02702561,
#          -0.0043564 , -0.04798392, -0.01499317, -0.02326448,
#          -0.00690408,  0.03454093],
#         [-0.02264737,  0.02763828, -0.00285298, -0.0406559 ,
#           0.03680868,  0.01323486,  0.0464117 , -0.04980272,
#           0.01985571, -0.03430444],
#         [-0.01883961, -0.03607448, -0.04346418, -0.00464296,
#          -0.02122625,  0.02094008,  0.03548387, -0.02125642,
#           0.006692  ,  0.04350139],
#         [ 0.00141754,  0.02117649, -0.02638456, -0.00134147,
#          -0.01572875, -0.01362541, -0.04430502, -0.02442248,
#          -0.03943612, -0.04176552]],
#
#        [[-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [ 0.03465659,  0.02488242,  0.01882757,  0.02702561,
#          -0.0043564 , -0.04798392, -0.01499317, -0.02326448,
#          -0.00690408,  0.03454093],
#         [ 0.01688256,  0.04838968,  0.01894852,  0.01827073,
#           0.04447946, -0.0059068 ,  0.01868321,  0.04025928,
#          -0.02938609, -0.02693783],
#         [-0.01883961, -0.03607448, -0.04346418, -0.00464296,
#          -0.02122625,  0.02094008,  0.03548387, -0.02125642,
#           0.006692  ,  0.04350139],
#         [ 0.03005359, -0.02119946,  0.00706054, -0.00223627,
#           0.0114509 ,  0.01859326, -0.00338886, -0.0389241 ,
#          -0.03247656, -0.0070347 ]],
#
#        [[-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [ 0.02864684,  0.03736074, -0.00773435, -0.02354604,
#           0.03613881, -0.02174629, -0.00202099,  0.04916928,
#           0.01761517,  0.02680791],
#         [-0.01939674, -0.04171317,  0.04224399,  0.00317989,
#          -0.01858758, -0.01116946, -0.04527792, -0.0216719 ,
#           0.02233047,  0.02186887],
#         [ 0.03441605,  0.01813849, -0.04130558, -0.04189683,
#           0.04386162, -0.04378561, -0.0037057 , -0.04874203,
#          -0.01605282,  0.04679698],
#         [-0.03549304,  0.03632197, -0.02992817,  0.03459184,
#           0.0028531 ,  0.02175337, -0.00326753,  0.0488972 ,
#          -0.03914822, -0.02440828],
#         [-0.04395344, -0.00104589, -0.01301149,  0.00185634,
#          -0.01676934,  0.03594277, -0.04481831,  0.04923359,
#           0.04363178,  0.0147589 ]],
#
#        [[-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [ 0.02864684,  0.03736074, -0.00773435, -0.02354604,
#           0.03613881, -0.02174629, -0.00202099,  0.04916928,
#           0.01761517,  0.02680791],
#         [-0.01939674, -0.04171317,  0.04224399,  0.00317989,
#          -0.01858758, -0.01116946, -0.04527792, -0.0216719 ,
#           0.02233047,  0.02186887],
#         [ 0.03441605,  0.01813849, -0.04130558, -0.04189683,
#           0.04386162, -0.04378561, -0.0037057 , -0.04874203,
#          -0.01605282,  0.04679698],
#         [-0.03549304,  0.03632197, -0.02992817,  0.03459184,
#           0.0028531 ,  0.02175337, -0.00326753,  0.0488972 ,
#          -0.03914822, -0.02440828],
#         [-0.04959628,  0.0022953 , -0.0187123 , -0.01083909,
#          -0.02550014,  0.00360675,  0.0248615 , -0.00809448,
#          -0.01374477, -0.04816127]],
#
#        [[-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [ 0.00607486,  0.03445344, -0.0037594 ,  0.04833889,
#           0.02511753,  0.01595936,  0.0098932 ,  0.04395879,
#           0.03740323, -0.01178424],
#         [ 0.03465659,  0.02488242,  0.01882757,  0.02702561,
#          -0.0043564 , -0.04798392, -0.01499317, -0.02326448,
#          -0.00690408,  0.03454093],
#         [-0.0472013 , -0.02839611,  0.04143004,  0.01015314,
#          -0.02214934,  0.04101506, -0.00784781, -0.01502556,
#          -0.02179589,  0.0435117 ],
#         [-0.01883961, -0.03607448, -0.04346418, -0.00464296,
#          -0.02122625,  0.02094008,  0.03548387, -0.02125642,
#           0.006692  ,  0.04350139],
#         [ 0.02946099,  0.00594737,  0.0144959 ,  0.04359633,
#          -0.04370707, -0.01267071, -0.04949802, -0.04455091,
#           0.00616521,  0.02937788]],
#
#        [[-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02788483, -0.01242678,  0.04210098, -0.02437191,
#          -0.04098518, -0.01757019,  0.00017288, -0.00713043,
#           0.00117327,  0.01571984],
#         [-0.02980428,  0.01378066,  0.02142194, -0.03111773,
#           0.04768885, -0.02663767,  0.02914738,  0.02011638,
#          -0.01939211, -0.03862673],
#         [ 0.0031382 , -0.00668667,  0.00060673,  0.03530223,
#          -0.0039538 , -0.03574967, -0.04552964, -0.01303024,
#           0.02696225,  0.02815421],
#         [-0.01047001, -0.02831677, -0.04536576, -0.03313493,
#          -0.02103503,  0.02695603,  0.01959235, -0.03878077,
#          -0.02455059, -0.01082504],
#         [-0.03549304,  0.03632197, -0.02992817,  0.03459184,
#           0.0028531 ,  0.02175337, -0.00326753,  0.0488972 ,
#          -0.03914822, -0.02440828]]], dtype=float32)
